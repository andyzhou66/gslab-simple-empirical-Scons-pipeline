# %%
import pandas as pd
import os
import sys
from dotenv import load_dotenv

# %%
from pathlib import Path

# %%
print(os.getcwd())
print('Hi')
print('Hi')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(os.getcwd())
#       2 print('Hi')
#
# NameError: name 'os' is not defined

# %%
script_dir = Path(__file__).resolve().parent          # .../1.import-data/code/
env_path   = script_dir.parent / ".env"               # .../1.import-data/.env
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 script_dir = Path(__file__).resolve().parent          # .../1.import-data/code/
#       2 env_path   = script_dir.parent / ".env"               # .../1.import-data/.env
#
# NameError: name '__file__' is not defined

# %%
print('test')
# Out:
# test
